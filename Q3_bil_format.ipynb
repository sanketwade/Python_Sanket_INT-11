# %%
from random import randint
bil_no = randint(0, 1000)
import datetime
from random import randint
import time
from datetime import date
today = date.today()
date = today.strftime("%d-%m-%Y")
bil_no  = randint(0,1000)
# current_date = datetime.datetime.today().date()
# check_in = current_date - datetime.timedelta(days = stay)
# check_in = check_in.strftime("%d-%m-%Y")





# while loop for guest information
No_of_person = 1
# room_num = 0
# ID = " "
# lodging_charge = 0
# dining_charge = 0
# No_of_person = 0
# loundary_charge = 0
# ex_person_charge = 0
# other_charge = 0
user_input = ""
list_data = []

while True:
    user_input = input("Enter Guest Name: ")
    list_data.append(user_input)
    name = user_input
    print(name)
    user_input = (input("Enter the number of guest:"))
    list_data.append(user_input)
    No_of_person = int(user_input)

    user_input = int(input("Enter the number of days stay: "))
    list_data.append(user_input)
    stay = user_input

    user_input = int(input("Enter the Lodging Charge: "))
    list_data.append(user_input)
    lodging_charge = float(user_input)
    room_rent = lodging_charge
    print(room_rent)

    user_input = int(input("Enter room Number: "))
    list_data.append(user_input)
    room_num = user_input
    print(room_num)

    print("Enter 'press spacebar' to Submit ")
    if input() == " ":
        break

    user_input = input("Enter Guest ID No: ")
    list_data.append(user_input)
    guest_id = user_input
    print(guest_id)
    print("Enter 'press spacebar' to Submit ")


    user_input = int(input("Enter Dining Charge: "))
    list_data.append(user_input)
    dining_charge = user_input
    print(dining_charge)
    print("Enter 'press spacebar' to Submit ")

    user_input = int(input("Enter the Loundary Charge: "))
    list_data.append(user_input)
    loundary_charge = user_input
    print(loundary_charge)
    print("Enter 'press spacebar' to Submit ")

    user_input = int(input("Enter the Extra Person Charge: "))
    list_data.append(user_input)
    ex_person_charge = int(user_input)
    print(ex_person_charge)
    print("Enter 'press spacebar' to Submit ")

    user_input = int(input("Enter the Others Charges: "))
    list_data.append(user_input)
    other_charge = user_input
    print(other_charge)
    print("Enter 'press spacebar' to Submit ")
    break



total = (lodging_charge * No_of_person ) + loundary_charge + dining_charge + other_charge + ex_person_charge
GST = total * 0.18
final_bil = total + GST

current_date = datetime.datetime.today().date()
check_in = current_date - datetime.timedelta(days = stay)
check_in = check_in.strftime("%d-%m-%Y")



hotel_name = "Hotel Sanket & Friends"
est_year = "Since 1995" 
Address = "\t\t\t     Nimkarda,Taluka Balapur"+"                                     |\n|\t\t\t         Akola 444109"
print("_"*90)

print("|"+"Bil No: " + "{}".format(bil_no)+ "\t\t\t\t\t\t\t\tDate: "+ "{}".format(date) +" |")
print(f"|{hotel_name.center(80)}        |")
print(f"|{Address.center(8)}\t\t\t\t\t\t |")
print("_"*90)
print("|  Guest Name :" + "{}".format(name) + "\t\t\t                       Date Of Arrival:" + "{}".format(check_in) +"|")
print("|"+ " "*88+"|")
print("|  No of Persons:"+"{}".format(No_of_person)+"                                             ID No:"+"{}".format(guest_id)+  "       \t\t |" )
print("|  Room No: " + "{}".format(room_num)+"                  Room Rent: " + "{}".format(room_rent) +"              Check Out:"+" {}".format(date)+"    \t |")

print("_"*90)

print("|                     PERTICULARS\t\t\t|"+ " \tAmmount (Rs)" + "\t\t |")
print("_"*90)

print("|                     Lodging Charge:\t\t\t|"+ "\t\t{}".format(No_of_person)+ "X""{}".format(lodging_charge)+"\t\t |") 
print("|                     Dining Charge:\t\t\t|"+ "\t\t{}".format(dining_charge)+ "\t\t |") 
print("|                     Loundary Charge:\t\t\t|"+ "\t\t{}".format(loundary_charge)+ "\t\t |")  
print("|                     Extra Person Charge:\t\t|"+"\t\t{}".format(ex_person_charge)+ "\t\t |")  
print("|                     Others :\t\t\t\t|"+"\t\t{}".format(other_charge)+ "\t\t |")
print("_"*90)
print("|                     Total Ammount:\t\t\t|"+"   {}".format(total)+" + ""{} GST".format(GST)+" = ""{}".format(final_bil)+"  |")  
print("_"*90)
# Out:
# __________________________________________________________________________________________
# |Bil No: 76								Date: 20-01-2025 |
# |                             Hotel Sanket & Friends                                     |
# |			     Nimkarda,Taluka Balapur                                     |
# |			         Akola 444109						 |
# __________________________________________________________________________________________
# |  Guest Name :sanket			                       Date Of Arrival:18-01-2025|
# |                                                                                        |
# |  No of Persons:2                                             ID No:2       		 |
# |  Room No: 2                  Room Rent: 2.0              Check Out: 20-01-2025    	 |
# __________________________________________________________________________________________
# |                     PERTICULARS			| 	Ammount (Rs)		 |
# ...
